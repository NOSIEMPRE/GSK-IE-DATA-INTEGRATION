# %% [markdown]
# # Scenario 1 — Baseline Anomaly Detection
#
# **Rule-based checks + Isolation Forest** (single field)
#
# - Rules: required fields, time logic, referential integrity
# - AI: Isolation Forest on `drug_exposure.quantity` or `measurement.value_as_number`
# - Output: quality report JSON, logged to MLflow
#
# > Prerequisite: `data/synthea1k.duckdb` must exist

# %%
import subprocess
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd()
if not (PROJECT_ROOT / "02-data-sampling-feature").exists():
    PROJECT_ROOT = PROJECT_ROOT.parent

print("Running validation + anchor + MLflow... (this may take 10–30 s)")
subprocess.run(
    [sys.executable, "03-experiment-tracking/run_with_mlflow.py", "--scenario", "scenario1"],
    check=True,
    cwd=PROJECT_ROOT,
)
print("Done. Run: mlflow ui (from project root) to view.")
# Out:
# Running validation + anchor + MLflow... (this may take 10–30 s)
# Quality report written to: /Users/isabelwu/Desktop/GSK DATA INTEGRATION/data/quality_reports/quality_report_20260312_152603.json
# Summary: 39 passed, 0 warnings, 0 failed
# Provenance manifest written to: /Users/isabelwu/Desktop/GSK DATA INTEGRATION/data/provenance/provenance_manifest_20260312_152603.json
# Anchored 5/5 assets
#   [anchored] OMOP snapshot: 5fe7988f0dcb6596...
#   [anchored] ETL spec: load: 2c0684b7207a14e3...
#   [anchored] ETL spec: download: 6c2dcd7b2ae60b50...
#   [anchored] Validation script: 563924d611b3a319...
#   [anchored] Quality report (latest): 287e26b6c09c17e5...
# Logged to MLflow experiment: rwd-trustchain-quality (scenario=scenario1)
# View with: mlflow ui
# Done. Run: mlflow ui (from project root) to view.
